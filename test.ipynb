# %%
import pandas as pd

# %%
df = pd.read_csv("./data.csv")
# Out:
# /var/folders/tn/my7fmgyj3gx8811h_mwsw1mh0000gn/T/ipykernel_92652/1725613181.py:1: DtypeWarning: Columns (33,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./data.csv")

# %%
df
# Out:
#                            Name Sex Event   Equipment   Age AgeClass  \
# 0                   Alona Vladi   F   SBD         Raw  33.0    24-34
# 1            Galina Solovyanova   F   SBD         Raw  43.0    40-44
# 2                Daniil Voronin   M   SBD         Raw  15.5    16-17
# 3                Aleksey Krasov   M   SBD         Raw  35.0    35-39
# 4        Margarita Pleschenkova   M   SBD         Raw  26.5    24-34
# ...                         ...  ..   ...         ...   ...      ...
# 2872615            Inna Orobets   F   SBD  Single-ply  45.0    45-49
# 2872616             Ágnes Szabó   F   SBD  Single-ply  27.5    24-34
# 2872617   Brenda van der Meulen   F   SBD  Single-ply  37.5    35-39
# 2872618            Kelly Phasey   F   SBD  Single-ply  39.5    35-39
# 2872619  Hildeborg Juvet Hugdal   F   SBD  Single-ply  32.5    24-34
#
#         BirthYearClass Division  BodyweightKg WeightClassKg  ...  Tested  \
# ...
